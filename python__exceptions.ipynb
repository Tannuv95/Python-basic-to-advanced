# %% [markdown]
# <a href="https://colab.research.google.com/github/Tannuv95/Python-basic-to-advanced/blob/main/python__exceptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is my first code in Github codespace")
    #print("Hello Git hub") IndentationError: unexpected indent

a=6
'''if (a<10)
    print("a is less than 10")
    This will give syntax error as SyntaxError: expected ':'
'''

#Logical Errors

#1/0 #ZeroDivisionError: division by zero

'''a=10
b=4
print("Addition",a+c) '''

#NameError: name 'c' is not defined name error is come when name is not defined

print(dir(locals()['__builtins__']))  # some builtins exceptions

#Some Exceptions error
#Asssertion Error: Assertion checks a condition prior to running module, halting execution if the condition is False.

z=1
y=5
assert y!=3,"Inavalid error"
print(z/y)

#Attribute Error : When we assigning some values that we can't do it
'''y=6
y.append(6)'''

# Handeling error
#  We can handle errors using try,except,else and finally

# Handeling ZeroDivisionError

try:
    a=10
    b=0
    c=a/b
    print(c)
except:
    print("Can't divide with zero provide different number")

try:
    f=open("text.txt","r")
    f.write("Ineuron")
except:
    print("there was mistake")

print("this is souter block")


'''s=[4,5,6,7,8,9,9]

try:
    for i in range(len(s)+1):
        print(s[i])
except Exception as e:
    print(e)
    print("this is not working")'''

'''
a=int(input())
b=int(input())

try:
    a=int(input("enter value of a:"))
    b=int(input("enter value of b:"))
    c=a/b
    print("answer",c)
except ValueError:
    print("Entered value is wrong")
except ZeroDivisionError:
    print("Cannot divide by zero")
'''

import sys

randonlist=['a',0,2]

for entry in randonlist:
    try:
        print("the entry is",entry)
        r=1/int(entry)
        break
    except:
        print("oops",sys.exc_info(),"occured")
        print("next entry")
print("The reciprocal of",entry,"is",r)


'''try:
    #block of code
except Exceptions:
    #block of code
else:
    #this code excecutes when exception not occured'''

try:
    a=int(input("Input a number:"))
    assert a%2==0
    print("number is even")
except:
    print("Odd number")
finally:
    print("finally block is always be excecuted")
